# %%
# 1. Install required packages on the active execution backend
# %pip install faiss-cpu sentence-transformers datasets transformers accelerate --quiet

# 2. Verify if the execution backend sees the Hosted GPU
import torch
print("\n--- Hardware Check ---")
print("Is CUDA available?:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Using GPU:", torch.cuda.get_device_name(0))

# 3. Move into the working directory and run the evaluation script
# %cd /kaggle/working
# !python run_worker_t04.py
